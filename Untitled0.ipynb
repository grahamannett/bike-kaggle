# %%
import pandas as pd
import numpy as np
import csv
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv('data/train.csv')
test = pd.read_csv('data/test.csv')

# %%
time = [item.split(' ')[1] for item in df['datetime']]
date = pd.Series([item.split(' ')[0] for item in df['datetime']])

#update and rename
df['datetime'].update(date)
df['time'] = time
df.rename(columns={'datetime':'date'},inplace=True)

#move time over to date
col = df.columns.tolist()
col = col[-1:]+col[:-1]
col[0], col[1] = col[1], col[0]
df = df[col]

# %%
time = [item.split(' ')[1] for item in test['datetime']]
date = pd.Series([item.split(' ')[0] for item in test['datetime']])

#update and rename
test['datetime'].update(date)
test['time'] = time
test.rename(columns={'datetime':'date'},inplace=True)

#move time over to date
col = test.columns.tolist()
col = col[-1:]+col[:-1]
col[0], col[1] = col[1], col[0]
test = test[col]

# %%
df['time'] = df['time'].str.replace(':','')
test['time'] = test['time'].str.replace(':','')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-5be6f34c7d7a> in <module>()
#       1 df['time'] = df['time'].str.replace(':','')
# ----> 2 test['time'] = test['time'].str.replace(':','')
#
# /usr/local/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1656             return self._getitem_multilevel(key)
#    1657         else:
# -> 1658             return self._getitem_column(key)
#    1659
#    1660     def _getitem_column(self, key):
#
# /usr/local/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1663         # get column
#    1664         if self.columns.is_unique:
# -> 1665             return self._get_item_cache(key)
#    1666
#    1667         # duplicate columns & possible reduce dimensionaility
#
# ...

# %%
df
# Out:
#           date    time  season  holiday  workingday  weather   temp   atemp  \
# 0   2011-01-01  000000       1        0           0        1   9.84  14.395
# 1   2011-01-01  010000       1        0           0        1   9.02  13.635
# 2   2011-01-01  020000       1        0           0        1   9.02  13.635
# 3   2011-01-01  030000       1        0           0        1   9.84  14.395
# 4   2011-01-01  040000       1        0           0        1   9.84  14.395
# 5   2011-01-01  050000       1        0           0        2   9.84  12.880
# 6   2011-01-01  060000       1        0           0        1   9.02  13.635
# 7   2011-01-01  070000       1        0           0        1   8.20  12.880
# 8   2011-01-01  080000       1        0           0        1   9.84  14.395
# 9   2011-01-01  090000       1        0           0        1  13.12  17.425
# 10  2011-01-01  100000       1        0           0        1  15.58  19.695
# ...

# %%
#random forest
forest = RandomForestClassifier(n_estimators=5)

target = df['casual'].values
train = df.drop({'date','registered','count'}, axis=1).values
forest.fit(train,target)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-46ae72391823> in <module>()
#       2 forest = RandomForestClassifier(n_estimators=5)
#       3
# ----> 4 target = df['casual'].values
#       5 train = df.drop({'date','registered','count'}, axis=1).values
#       6 forest.fit(train,target)
#
# /usr/local/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1656             return self._getitem_multilevel(key)
#    1657         else:
# -> 1658             return self._getitem_column(key)
#    1659
#    1660     def _getitem_column(self, key):
#
# /usr/local/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1663         # get column
#    1664         if self.columns.is_unique:
# -> 1665             return self._get_item_cache(key)
#    1666
# ...
